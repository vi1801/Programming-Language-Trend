# %% [markdown]
# <a href="https://colab.research.google.com/github/vi1801/Programming-Language-Trend/blob/main/ProgrammingLanguageTrends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/Popularity of Programming Languages from 2004 to 2023.csv')

data['Date'] = pd.to_datetime(data['Date'])

data.set_index('Date', inplace = True)

data.head()
# Out:
#             Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  Groovy  \
# Date
# 2004-07-01  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0    0.03
# 2004-08-01  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0    0.07
# 2004-09-01  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0    0.08
# 2004-10-01  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0    0.09
# 2004-11-01  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0    0.07
#
#             Haskell  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# Date                 ...
# 2004-07-01     0.22  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0
# 2004-08-01     0.20  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0
# 2004-09-01     0.21  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0
# 2004-10-01     0.20  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0
# 2004-11-01     0.24  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0
#
# ...

# %%
print(data.info)

print(data.describe)
# Out:
# <bound method DataFrame.info of             Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal    Go  Groovy  \
# Date
# 2004-07-01  0.34  0.36  10.01  4.68   0.42  0.00           2.80  0.00    0.03
# 2004-08-01  0.35  0.36   9.74  4.96   0.46  0.00           2.65  0.00    0.07
# 2004-09-01  0.41  0.41   9.59  5.04   0.51  0.00           2.64  0.00    0.08
# 2004-10-01  0.40  0.38   9.47  5.29   0.53  0.00           2.76  0.00    0.09
# 2004-11-01  0.38  0.38   9.48  5.22   0.55  0.00           2.75  0.00    0.07
# ...          ...   ...    ...   ...    ...   ...            ...   ...     ...
# 2023-01-01  0.46  0.85   6.84  6.93   0.39  0.82           0.00  1.92    0.39
# 2023-02-01  0.46  0.89   6.84  6.92   0.37  0.82           0.02  1.93    0.36
# 2023-03-01  0.46  0.93   6.86  6.81   0.37  0.80           0.09  1.90    0.37
# 2023-04-01  0.46  0.95   6.73  6.82   0.39  0.81           0.13  1.96    0.33
# ...

# %%
import missingno as miss

miss.matrix(data)
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#              Abap         Ada       C/C++          C#       Cobol        Dart  \
# count  227.000000  227.000000  227.000000  227.000000  227.000000  227.000000
# mean     0.489692    0.361542    8.113348    7.496784    0.368194    0.176608
# std      0.107508    0.198476    1.774062    1.232928    0.072104    0.239022
# min      0.320000    0.090000    5.480000    4.680000    0.180000    0.000000
# 25%      0.400000    0.220000    6.800000    6.640000    0.320000    0.000000
# 50%      0.480000    0.320000    7.940000    7.200000    0.360000    0.090000
# 75%      0.560000    0.390000    8.675000    8.440000    0.405000    0.180000
# max      0.760000    1.020000   12.890000    9.940000    0.560000    0.880000
#
#        Delphi/Pascal          Go      Groovy     Haskell  ...  Powershell  \
# count     227.000000  227.000000  227.000000  227.000000  ...  227.000000
# mean        0.960661    0.476344    0.343128    0.292952  ...    0.650088
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 227 entries, 2004-07-01 to 2023-05-01
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   C/C++         227 non-null    float64
#  1   C#            227 non-null    float64
#  2   Java          227 non-null    float64
#  3   JavaScript    227 non-null    float64
#  4   Objective-C   227 non-null    float64
#  5   PHP           227 non-null    float64
#  6   Python        227 non-null    float64
#  7   Visual Basic  227 non-null    float64
# dtypes: float64(8)
# memory usage: 16.0 KB

# %%
res = data.columns.tolist()
res
# Out:
# ['C/C++',
#  'C#',
#  'Java',
#  'JavaScript',
#  'Objective-C',
#  'PHP',
#  'Python',
#  'Visual Basic']

# %%
import seaborn as sns
plt.figure(figsize = (15, 8))
sns.set(style = 'dark')

for language in clms:
    sns.lineplot(x = data.index, y = data[language], label = language)

plt.ylabel('Popularity', fontsize = 12)
plt.xlabel('Year', fontsize = 12)
plt.title('Popular Prgramming Languages', fontsize = 20)
plt.legend(loc = 2)
plt.yticks(fontsize = 10)
plt.xticks(rotation = 45, fontsize = 10)
plt.tight_layout()
plt.show()
